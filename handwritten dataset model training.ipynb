# %%
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %%
(X_train, y_train) , (X_test, y_test) = keras.datasets.mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step

# %%
X_train[0].shape
# Out:
# (28, 28)

# %%
plt.matshow(X_train[
  0])

# %%
X_train = X_train / 255
X_test = X_test / 255

# %%
X_train_flattened = X_train.reshape(len(X_train), 28*28)
X_test_flattened = X_test.reshape(len(X_test), 28*28)

# %%
X_train_flattened.shape
# Out:
# (60000, 784)

# %%
y_predicted_labels = [np.argmax(i) for i in y_predicted]

# %%
cm = tf.math.confusion_matrix(labels=y_test,predictions=y_predicted_labels)
cm
# Out:
# <tf.Tensor: shape=(10, 10), dtype=int32, numpy=
# array([[ 959,    0,    1,    2,    0,    5,    5,    3,    4,    1],
#        [   0, 1111,    3,    2,    0,    1,    4,    2,   12,    0],
#        [   4,   11,  920,   16,    6,    2,   13,   10,   45,    5],
#        [   2,    0,   19,  912,    0,   24,    2,   11,   30,   10],
#        [   1,    1,    6,    1,  898,    0,   12,    4,   13,   46],
#        [  10,    3,    5,   28,    9,  764,   12,    7,   46,    8],
#        [  10,    3,    8,    0,    7,   11,  910,    2,    7,    0],
#        [   1,    7,   23,    3,    7,    0,    0,  942,    5,   40],
#        [   5,    8,    5,   14,    9,   15,    7,    7,  896,    8],
#        [   9,    7,    2,    9,   17,    2,    0,   13,   11,  939]],
#       dtype=int32)>

# %%
import seaborn as sn
plt.figure(figsize = (10,7))
sn.heatmap(cm, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(95.72222222222221, 0.5, 'Truth')

# %%
model = keras.Sequential([
    keras.layers.Dense(10, input_shape=(784,), activation='sigmoid')
])

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model.fit(X_train_flattened, y_train, epochs=5)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8122 - loss: 0.7227
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9128 - loss: 0.3150
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.9198 - loss: 0.2836
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - accuracy: 0.9219 - loss: 0.2756
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - accuracy: 0.9240 - loss: 0.2750

# %%
model = keras.Sequential([
    keras.layers.Dense(45, input_shape=(784,), activation='sigmoid'),
    keras.layers.Dense(16, activation='sigmoid'),
    keras.layers.Dense(32, activation='sigmoid'),
    keras.lay`  ers.Dense(10, activation='sigmoid')
])

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model.fit(X_train_flattened, y_train, epochs=5)
# Out:
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.5392 - loss: 1.5770
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9120 - loss: 0.3462
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9437 - loss: 0.2087
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9558 - loss: 0.1584
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9632 - loss: 0.1299

# %% [markdown]
# above is with more layers which is i think not working properly.

# %%
model.evaluate(X_test_flattened,y_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9524 - loss: 0.1649
# [0.1457921862602234, 0.9574999809265137]

# %%
import matplotlib.pyplot as plt
from tensorflow import keras

# Define the model
model = keras.Sequential([
    keras.layers.Dense(16, input_shape=(784,), activation='sigmoid'),
    keras.layers.Dense(16, activation='sigmoid'),
    keras.layers.Dense(10, activation='sigmoid')
])

# Compile the model
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# Fit the model and store the history
history = model.fit(X_train_flattened, y_train, epochs=5)

# Extract the accuracy and epochs from the history
epochs = range(1, len(history.history['accuracy']) + 1)
training_accuracy = history.history['accuracy']

# Plot the accuracy vs epochs
plt.figure(figsize=(10, 6))
plt.plot(epochs, training_accuracy, marker='o', label='Training Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Training Accuracy vs. Epochs')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.6250 - loss: 1.6045
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8940 - loss: 0.4280
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9158 - loss: 0.3051
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.9258 - loss: 0.2659
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9336 - loss: 0.2364

# %%
model = keras.Sequential([
    keras.layers.Dense(79, input_shape=(784,), activation='sigmoid'),
    keras.layers.Dense(16, activation='sigmoid'),
    keras.layers.Dense(10, activation='sigmoid')
])

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model.fit(X_train_flattened, y_train, epochs=5)


# Fit the model and store the history
history = model.fit(X_train_flattened, y_train, epochs=5)

# Extract the accuracy and epochs from the history
epochs = range(1, len(history.history['accuracy']) + 1)
training_accuracy = history.history['accuracy']

# Plot the accuracy vs epochs
plt.figure(figsize=(10, 6))
plt.plot(epochs, training_accuracy, marker='o', label='Training Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Training Accuracy vs. Epochs')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.7246 - loss: 1.2462
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9293 - loss: 0.2771
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.9517 - loss: 0.1808
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9632 - loss: 0.1327
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9723 - loss: 0.1029
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9756 - loss: 0.0874
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9802 - loss: 0.0728
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.9828 - loss: 0.0630
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9858 - loss: 0.0544
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.9875 - loss: 0.0461

# %%
import matplotlib.pyplot as plt
from tensorflow import keras

# Define the model
model = keras.Sequential([
    keras.layers.Dense(16, input_shape=(784,), activation='relu'),
    keras.layers.Dense(16, activation='relu'),
    keras.layers.Dense(10, activation='relu')
])

# Compile the model
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# Fit the model and store the history
history = model.fit(X_train_flattened, y_train, epochs=5)

# Extract the accuracy and epochs from the history
epochs = range(1, len(history.history['accuracy']) + 1)
training_accuracy = history.history['accuracy']

# Plot the accuracy vs epochs
plt.figure(figsize=(10, 6))
plt.plot(epochs, training_accuracy, marker='o', label='Training Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Training Accuracy vs. Epochs')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.1050 - loss: 2.8609
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.0997 - loss: 2.3034
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.0982 - loss: 2.3026
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.0977 - loss: 2.3026
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.0995 - loss: 2.3026

# %%
import matplotlib.pyplot as plt
import numpy as np

# Replace these with your actual accuracy data
epochs = np.arange(1, 6)  # Number of epochs
training_accuracy = [0.85, 0.87, 0.88, 0.89, 0.91]  # Replace with your training accuracy values
test_accuracy = [0.83, 0.85, 0.86, 0.87, 0.88]      # Replace with your test accuracy values

# Plotting the accuracy vs. epochs
plt.figure(figsize=(10, 6))
plt.plot(epochs, training_accuracy, marker='o', label='Training Accuracy')
plt.plot(epochs, test_accuracy, marker='s', label='Test Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Accuracy vs. Epochs')
plt.legend()
plt.grid(True)
plt.show()

# %%
model.evaluate(X_test_flattened,y_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9601 - loss: 0.1306
# [0.11559318751096725, 0.9656999707221985]

# %%
model = keras.Sequential([
    keras.layers.Dense(16, input_shape=(784,), activation='relu'),
    keras.layers.Dense(16, activation='relu'),
    keras.layers.Dense(10, activation='relu')
])

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model.fit(X_train_flattened, y_train, epochs=5)
# Out:
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.5629 - loss: 2.0881
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.1120 - loss: 2.2692
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - accuracy: 0.1002 - loss: 2.2975
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.0999 - loss: 2.2991
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.0977 - loss: 2.3015

# %%
model = keras.Sequential([
    keras.layers.Dense(16, input_shape=(784,), activation='sigmoid'),
    keras.layers.Dense(16, activation='sigmoid'),
    keras.layers.Dense(10, activation='sigmoid')
])

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model.fit(X_train_flattened, y_train, epochs=5)
# Out:
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.5582 - loss: 1.6684
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8989 - loss: 0.4409
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9189 - loss: 0.3019
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9259 - loss: 0.2599
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9348 - loss: 0.2282

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.datasets import mnist

# Load the MNIST dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Normalize pixel values to be between 0 and 1
x_train, x_test = x_train / 255.0, x_test / 255.0

# Define the model
model = keras.models.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)),  # Input layer with 784 neurons (28x28)
    keras.layers.Dense(16, activation='sigmoid'),  # Hidden layer 1 with 16 neurons
    keras.layers.Dense(16, activation='sigmoid'),  # Hidden layer 2 with 16 neurons
    keras.layers.Dense(10, activation='sigmoid')  # Output layer with 10 neurons
])

# Define precision and recall metrics outside of the custom functions
precision_metric = tf.keras.metrics.Precision()
recall_metric = tf.keras.metrics.Recall()

# Custom precision and recall functions
def custom_precision(y_true, y_pred):
    y_pred_labels = tf.argmax(y_pred, axis=-1)  # Convert predictions to class labels
    precision_metric.update_state(y_true, y_pred_labels)
    return precision_metric.result()

def custom_recall(y_true, y_pred):
    y_pred_labels = tf.argmax(y_pred, axis=-1)  # Convert predictions to class labels
    recall_metric.update_state(y_true, y_pred_labels)
    return recall_metric.result()

# Compile the model with custom precision and recall
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy', custom_precision, custom_recall])

# Train the model
model.fit(x_train, y_train, epochs=5)

# Reset metrics after evaluation
precision_metric.reset_state()
recall_metric.reset_state()


# Evaluate the model
test_loss, test_acc, test_precision, test_recall = model.evaluate(x_test, y_test, verbose=2)

# Print evaluation results
print('\nTest Accuracy:', test_acc)
print('Test Precision:', test_precision)
print('Test Recall:', test_recall)
model.summary()
# Out:
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.5185 - custom_precision: 0.8277 - custom_recall: 0.4203 - loss: 1.6680
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8955 - custom_precision: 0.9938 - custom_recall: 0.8908 - loss: 0.4442
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9197 - custom_precision: 0.9948 - custom_recall: 0.9373 - loss: 0.2991
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.9322 - custom_precision: 0.9954 - custom_recall: 0.9551 - loss: 0.2510
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9376 - custom_precision: 0.9957 - custom_recall: 0.9645 - loss: 0.2274
# 313/313 - 1s - 2ms/step - accuracy: 0.9375 - custom_precision: 0.9985 - custom_recall: 0.9923 - loss: 0.2257
#
# Test Accuracy: 0.9375
# Test Precision: 0.9985042214393616
# Test Recall: 0.9922601580619812
# Model: "sequential_9"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ flatten_3 (Flatten)                  │ (None, 784)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_25 (Dense)                     │ (None, 16)                  │          12,560 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_26 (Dense)                     │ (None, 16)                  │             272 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_27 (Dense)                     │ (None, 10)                  │             170 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 39,008 (152.38 KB)
#  Trainable params: 13,002 (50.79 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 26,006 (101.59 KB)

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.datasets import mnist

# Load the MNIST dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Normalize pixel values to be between 0 and 1
x_train, x_test = x_train / 255.0, x_test / 255.0

# Define the model
model = keras.models.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)),  # Flatten the input to 1D
    keras.layers.Dense(79, activation='sigmoid'),
    keras.layers.Dense(16, activation='sigmoid'),
    keras.layers.Dense(10, activation='sigmoid')
])

# Define precision and recall metrics outside of the custom functions
precision_metric = tf.keras.metrics.Precision()
recall_metric = tf.keras.metrics.Recall()

# Custom precision and recall functions
def custom_precision(y_true, y_pred):
    y_pred_labels = tf.argmax(y_pred, axis=-1)  # Convert predictions to class labels
    precision_metric.update_state(y_true, y_pred_labels)
    return precision_metric.result()

def custom_recall(y_true, y_pred):
    y_pred_labels = tf.argmax(y_pred, axis=-1)  # Convert predictions to class labels
    recall_metric.update_state(y_true, y_pred_labels)
    return recall_metric.result()

# Compile the model with custom precision and recall
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy', custom_precision, custom_recall])

# Train the model
model.fit(x_train, y_train, epochs=5)

# Reset metrics after evaluation
precision_metric.reset_state()
recall_metric.reset_state()

# Evaluate the model
test_loss, test_acc, test_precision, test_recall = model.evaluate(x_test, y_test, verbose=2)

# Print evaluation results
print('\nTest Accuracy:', test_acc)
print('Test Precision:', test_precision)
print('Test Recall:', test_recall)

# Display model summary
model.summary()
# Out:
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 40s 3ms/step - accuracy: 0.6795 - custom_precision: 0.9847 - custom_recall: 0.9201 - loss: 1.2326
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.9298 - custom_precision: 0.9956 - custom_recall: 0.9831 - loss: 0.2733
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9529 - custom_precision: 0.9964 - custom_recall: 0.9890 - loss: 0.1711
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.9621 - custom_precision: 0.9968 - custom_recall: 0.9914 - loss: 0.1305
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.9719 - custom_precision: 0.9972 - custom_recall: 0.9929 - loss: 0.1015
# 313/313 - 1s - 4ms/step - accuracy: 0.9670 - custom_precision: 0.9992 - custom_recall: 0.9964 - loss: 0.1104
#
# Test Accuracy: 0.9670000076293945
# Test Precision: 0.9992482662200928
# Test Recall: 0.9963809847831726
# Model: "sequential_12"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ flatten_4 (Flatten)                  │ (None, 784)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_34 (Dense)                     │ (None, 79)                  │          62,015 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_35 (Dense)                     │ (None, 16)                  │           1,280 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_36 (Dense)                     │ (None, 10)                  │             170 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 190,397 (743.74 KB)
#  Trainable params: 63,465 (247.91 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 126,932 (495.83 KB)

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.datasets import mnist

# Load the MNIST dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Normalize pixel values to be between 0 and 1
x_train, x_test = x_train / 255.0, x_test / 255.0

# Define the model with a Flatten layer
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)),  # Flatten the 28x28 input to 784
    keras.layers.Dense(16, activation='relu'),
    keras.layers.Dense(16, activation='relu'),
    keras.layers.Dense(10, activation='softmax')  # Use softmax for classification
])

# Define precision and recall metrics outside of the custom functions
precision_metric = tf.keras.metrics.Precision()
recall_metric = tf.keras.metrics.Recall()

# Custom precision and recall functions
def custom_precision(y_true, y_pred):
    y_pred_labels = tf.argmax(y_pred, axis=-1)  # Convert predictions to class labels
    precision_metric.update_state(y_true, y_pred_labels)
    return precision_metric.result()

def custom_recall(y_true, y_pred):
    y_pred_labels = tf.argmax(y_pred, axis=-1)  # Convert predictions to class labels
    recall_metric.update_state(y_true, y_pred_labels)
    return recall_metric.result()

# Compile the model with custom precision and recall
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy', custom_precision, custom_recall])

# Train the model
model.fit(x_train, y_train, epochs=5)

# Reset metrics after evaluation
precision_metric.reset_state()
recall_metric.reset_state()

# Evaluate the model
test_loss, test_acc, test_precision, test_recall = model.evaluate(x_test, y_test, verbose=2)

# Print evaluation results
print('\nTest Accuracy:', test_acc)
print('Test Precision:', test_precision)
print('Test Recall:', test_recall)

# Display model summary
model.summary()
# Out:
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.7785 - custom_precision: 0.9727 - custom_recall: 0.9912 - loss: 0.7247
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - accuracy: 0.9274 - custom_precision: 0.9942 - custom_recall: 0.9941 - loss: 0.2537
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.9400 - custom_precision: 0.9954 - custom_recall: 0.9950 - loss: 0.2080
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - accuracy: 0.9440 - custom_precision: 0.9958 - custom_recall: 0.9954 - loss: 0.1869
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.9501 - custom_precision: 0.9962 - custom_recall: 0.9958 - loss: 0.1696
# 313/313 - 1s - 2ms/step - accuracy: 0.9456 - custom_precision: 0.9979 - custom_recall: 0.9960 - loss: 0.1790
#
# Test Accuracy: 0.9455999732017517
# Test Precision: 0.9978871941566467
# Test Recall: 0.9960009455680847
# Model: "sequential_14"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ flatten_5 (Flatten)                  │ (None, 784)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_40 (Dense)                     │ (None, 16)                  │          12,560 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_41 (Dense)                     │ (None, 16)                  │             272 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_42 (Dense)                     │ (None, 10)                  │             170 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 39,008 (152.38 KB)
#  Trainable params: 13,002 (50.79 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 26,006 (101.59 KB)
